# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from selenium.webdriver.common.keys import Keys

service = Service('chromedriver')
service.start()

driver = webdriver.Remote(service.service_url)
driver.get("https://app.cpcbccr.com/AQI_India/")

# %%
def exception1():
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(4)
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(10)
    print("K=0 excep")
    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//span[normalize-space()='{}']".format(i)).click()
    time.sleep(5)

    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//td[@class='day'][normalize-space()='{}']".format(j)).click()
    time.sleep(4)
    driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
    #aqi=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
    #print(i+' '+j+' '+aqi)
    #aqi=[]
    #hr=[]
    driver.find_element_by_xpath("//input[@id='time']").click()
    driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
    driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
    #driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
    return driver
def exception2():
    service = Service('chromedriver')
    service.start()

    driver = webdriver.Remote(service.service_url)
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(4)
    print('drive')
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(10)
    print('drive')
    print("K!=0 excep")

    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(4)
    print('drive3')
    driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//span[normalize-space()='{}']".format(i)).click()
    time.sleep(5)

    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//td[@class='day'][normalize-space()='{}']".format(j)).click()
    time.sleep(4)
    #driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
    #aqi=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
    #print(i+' '+j+' '+aqi)
    #aqi=[]
    #hr=[]
    driver.find_element_by_xpath("//input[@id='time']").click()
    driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
    driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
    #driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
    return driver
def exception3():
    #service = Service('chromedriver')
    #service.start()

    #driver = webdriver.Remote(service.service_url)
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(50)
    print('j loop')
    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    print('j loop 3')
    time.sleep(40)
    driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
    time.sleep(40)
    print('j loop 4')
    driver.find_element_by_xpath("//span[normalize-space()='{}']".format(i)).click()
    time.sleep(50)
    print('j loop 5')
    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(40)
    driver.find_element_by_xpath("//td[@class='day'][normalize-space()='{}']".format(j)).click()
    time.sleep(40)
    return driver

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from selenium.webdriver.common.keys import Keys

service = Service('chromedriver')
service.start()

driver = webdriver.Remote(service.service_url)
driver.get("https://app.cpcbccr.com/AQI_India/")

from selenium.webdriver.common.keys import Keys
Apm2=[]
Apm10=[]
Ano2=[]
Anh3=[]
Aso2=[]
Aco=[]
Aoz=[]

minpm2=[]
minpm10=[]
minno2=[]
minnh3=[]
minso2=[]
minco=[]
minoz=[]

maxpm2=[]
maxpm10=[]
maxno2=[]
maxnh3=[]
maxso2=[]
maxco=[]
maxoz=[]

mon=[]
day=[]
hr=[]
aqi=[]
exc=[]

ex1=[]
ex2=[]
def AvgMinMax():
    avgPm2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[1]/td[3]').text 
    minP2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[1]/td[4]').text
    maxP2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[1]/td[5]').text

    avgPm1=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[2]/td[3]').text
    minP1=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[2]/td[4]').text
    maxP1=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[2]/td[5]').text


    avgNo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[3]/td[3]').text
    minNo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[3]/td[4]').text
    maxNo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[3]/td[5]').text

    avgNh3=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[4]/td[3]').text
    minNh3=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[4]/td[4]').text
    maxNh3=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[4]/td[5]').text

    avgSo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[5]/td[3]').text
    minSo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[5]/td[4]').text
    maxSo2=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[5]/td[5]').text

    avgCo=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[6]/td[3]').text
    minCo=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[6]/td[4]').text
    maxCo=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[6]/td[5]').text

    avgOz=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[7]/td[3]').text
    minOz=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[7]/td[4]').text
    maxOz=driver.find_element_by_xpath('//*[@id="data-available-panel"]/table/tbody/tr[7]/td[5]').text


    Apm2.append(avgPm2)
    Apm10.append(avgPm1)
    Ano2.append(avgNo2)
    Anh3.append(avgNh3)
    Aso2.append(avgSo2)
    Aco.append(avgCo)
    Aoz.append(avgOz)

    minpm2.append(minP2)
    minpm10.append(minP1)
    minno2.append(minNo2)
    minnh3.append(minNh3)
    minso2.append(minSo2)
    minco.append(minCo)
    minoz.append(minOz)

    maxpm2.append(maxP2)
    maxpm10.append(maxP1)
    maxno2.append(maxNo2)
    maxnh3.append(maxNh3)
    maxso2.append(maxSo2)
    maxco.append(maxCo)
    maxoz.append(maxOz)

for i in ['Jun','Sep']:
    driver.get("https://app.cpcbccr.com/AQI_India/")
    time.sleep(4)
    driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
    time.sleep(4)
    driver.find_element_by_xpath("//span[normalize-space()='{}']".format(i)).click()
    time.sleep(5)
    for j in range(1,31):
        try:
            j=str(j)
            print('j start')
            driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
            time.sleep(4)
            driver.find_element_by_xpath("//td[@class='day'][normalize-space()='{}']".format(j)).click()
            time.sleep(4)    #31
            print('ravi')
            driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
            driver.find_element_by_xpath("//input[@id='time']").click()
            driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
            driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
            for k in range(0,24):
                if k==0:
                    time.sleep(5)
                    try:
                        a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                    except:
                        print("K=0 exception")
                        driver=exception1()
                        driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
                        if k==0:
                            time.sleep(7)
                            a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                            mon.append(i)
                            day.append(j)
                            aqi.append(a)
                            hr.append(k)
                            AvgMinMax()
                            print(str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
                            continue
                        '''driver.find_element_by_xpath("//input[@id='time']").click()
                        driver.find_element_by_xpath("//a[@data-action='incrementHour']//span[@class='glyphicon glyphicon-chevron-up']").click()
                        if k!=0:
                            time.sleep(5)
                            a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                            mon.append(i)
                            day.append(j)
                            aqi.append(a)
                            hr.append(k)
                            AvgMinMax()
                            print('except '+str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
                            continue'''

                    mon.append(i)
                    day.append(j)
                    aqi.append(a)
                    hr.append(k)
                    AvgMinMax()
                    print(str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
                    continue
                #driver.find_element_by_xpath("//input[@id='time']").click()
                #driver.find_element_by_xpath("//a[@data-action='incrementHour']//span[@class='glyphicon glyphicon-chevron-up']").click()
                if k!=0:
                    time.sleep(5)
                    try:
                        driver.find_element_by_xpath("//input[@id='time']").click()
                        driver.find_element_by_xpath("//a[@data-action='incrementHour']//span[@class='glyphicon glyphicon-chevron-up']").click()
                        a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                    except:
                        print('exception2')
                        driver=exception2()
                        driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
                        '''if k==0:
                            time.sleep(5)
                            a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                            mon.append(i)
                            day.append(j)
                            aqi.append(a)
                            hr.append(k)
                            AvgMinMax()
                            print(str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
                            continue'''
                        #driver.find_element_by_xpath("//input[@id='time']").click()
                        #driver.find_element_by_xpath("//a[@data-action='incrementHour']//span[@class='glyphicon glyphicon-chevron-up']").click()
                        if k!=0:
                            time.sleep(5)
                            a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
                            mon.append(i)
                            day.append(j)
                            aqi.append(a)
                            hr.append(k)
                            AvgMinMax()
                            print('except '+str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
                            continue

                    mon.append(i)
                    day.append(j)
                    aqi.append(a)
                    hr.append(k)
                    AvgMinMax()
                    print(str(i)+' day: '+str(j)+' hour: '+str(k)+' aqi: '+str(a))
        except:
            print("j loop except")
            print(i)
            print(j)
            ex1.append(i)
            ex2.append(j)
            driver=exception3()
            continue
            '''service = Service('chromedriver')
            service.start()

            driver = webdriver.Remote(service.service_url)
            driver.get("https://app.cpcbccr.com/AQI_India/")
            time.sleep(200)
            print('j loop')
            driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
            print('j loop 3')
            time.sleep(40)
            driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
            time.sleep(40)
            print('j loop 4')
            driver.find_element_by_xpath("//span[normalize-space()='{}']".format(i)).click()
            time.sleep(50)
            print('j loop 5')
            driver.find_element_by_xpath("//div[@id='date']//i[@class='glyphicon glyphicon-th']").click()
            time.sleep(40)
            driver.find_element_by_xpath("//td[@class='day'][normalize-space()='{}']".format(j)).click()
            time.sleep(40)    #31 last'''
            #driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
            #aqi=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
            #print(i+' '+j+' '+aqi)
            #aqi=[]
            #hr=[]
            #driver.find_element_by_xpath("//input[@id='time']").click()
            #driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
            #driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(Keys.BACKSPACE)
            #driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
            #continue
# Out:
# j start
# ravi
# Jun day: 1 hour: 0 aqi:
# Jun day: 1 hour: 1 aqi:
# Jun day: 1 hour: 2 aqi:
# Jun day: 1 hour: 3 aqi:
# Jun day: 1 hour: 4 aqi:
# Jun day: 1 hour: 5 aqi: 73
# Jun day: 1 hour: 6 aqi: 236
# Jun day: 1 hour: 7 aqi: 264
# Jun day: 1 hour: 8 aqi: 113
# Jun day: 1 hour: 9 aqi: 180
# Jun day: 1 hour: 10 aqi: 125
# Jun day: 1 hour: 11 aqi: 153
# Jun day: 1 hour: 12 aqi: 130
# Jun day: 1 hour: 13 aqi: 141
# Jun day: 1 hour: 14 aqi: 156
# Jun day: 1 hour: 15 aqi: 140
# Jun day: 1 hour: 16 aqi: 108
# Jun day: 1 hour: 17 aqi: 250
# Jun day: 1 hour: 18 aqi: 154
# Jun day: 1 hour: 19 aqi: 255
# Jun day: 1 hour: 20 aqi: 189
# Jun day: 1 hour: 21 aqi: 207
# Jun day: 1 hour: 22 aqi: 188
# Jun day: 1 hour: 23 aqi: 168
# j start
# ravi
# Jun day: 2 hour: 0 aqi: 151
# Jun day: 2 hour: 1 aqi: 151
# Jun day: 2 hour: 2 aqi: 128
# Jun day: 2 hour: 3 aqi: 186
# Jun day: 2 hour: 4 aqi: 117
# Jun day: 2 hour: 5 aqi: 123
# Jun day: 2 hour: 6 aqi: 127
# Jun day: 2 hour: 7 aqi: 130
# Jun day: 2 hour: 8 aqi: 134
# Jun day: 2 hour: 9 aqi: 138
# Jun day: 2 hour: 10 aqi: 137
# Jun day: 2 hour: 11 aqi: 136
# Jun day: 2 hour: 12 aqi: 135
# Jun day: 2 hour: 13 aqi: 133
# Jun day: 2 hour: 14 aqi: 154
# Jun day: 2 hour: 15 aqi: 132
# Jun day: 2 hour: 16 aqi: 185
# Jun day: 2 hour: 17 aqi: 228
# Jun day: 2 hour: 18 aqi: 235
# Jun day: 2 hour: 19 aqi: 232
# Jun day: 2 hour: 20 aqi: 202
# Jun day: 2 hour: 21 aqi: 178
# Jun day: 2 hour: 22 aqi: 190
# Jun day: 2 hour: 23 aqi: 188
# j start
# ravi
# Jun day: 3 hour: 0 aqi: 171
# Jun day: 3 hour: 1 aqi: 171
# Jun day: 3 hour: 2 aqi: 155
# Jun day: 3 hour: 3 aqi: 138
# Jun day: 3 hour: 4 aqi: 121
# Jun day: 3 hour: 5 aqi: 106
# Jun day: 3 hour: 6 aqi: 105
# Jun day: 3 hour: 7 aqi: 107
# Jun day: 3 hour: 8 aqi: 111
# Jun day: 3 hour: 9 aqi: 115
# Jun day: 3 hour: 10 aqi: 123
# Jun day: 3 hour: 11 aqi: 128
# Jun day: 3 hour: 12 aqi: 166
# Jun day: 3 hour: 13 aqi: 200
# Jun day: 3 hour: 14 aqi: 263
# Jun day: 3 hour: 15 aqi: 158
# Jun day: 3 hour: 16 aqi: 158
# Jun day: 3 hour: 17 aqi: 158
# Jun day: 3 hour: 18 aqi: 177
# Jun day: 3 hour: 19 aqi: 256
# Jun day: 3 hour: 20 aqi: 223
# Jun day: 3 hour: 21 aqi: 161
# Jun day: 3 hour: 22 aqi: 203
# Jun day: 3 hour: 23 aqi: 164
# j start
# ravi
# Jun day: 4 hour: 0 aqi: 158
# Jun day: 4 hour: 1 aqi: 158
# Jun day: 4 hour: 2 aqi: 158
# Jun day: 4 hour: 3 aqi: 160
# Jun day: 4 hour: 4 aqi: 166
# Jun day: 4 hour: 5 aqi: 172
# exception2
# drive
# drive
# K!=0 excep
# drive3
# j loop except
# Jun
# 4
# j loop
# j loop 3
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-16-f78a50331739> in <module>
#     167                         driver.find_element_by_xpath("//a[@data-action='incrementHour']//span[@class='glyphicon glyphicon-chevron-up']").click()
# --> 168                         a=driver.find_element_by_xpath("//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]").text
#     169                     except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='panel panel-default aqi-panel']//div[@id='aqi-meter']//*[local-name()='svg']//*[name()='text'][2]/*[name()='tspan'][1]"}
#   (Session info: chrome=86.0.4240.198)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-16-f78a50331739> in <module>
#     170                         print('exception2')
# --> 171                         driver=exception2()
#     172                         driver.find_element_by_xpath("//input[@class='bootstrap-timepicker-hour']").send_keys(k)
#
# <ipython-input-11-c54dbf00fde8> in exception2()
#      43     print('drive3')
# ---> 44     driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
#      45     time.sleep(4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//th[normalize-space()='December 2020']"}
#   (Session info: chrome=86.0.4240.198)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-16-f78a50331739> in <module>
#     206             ex1.append(i)
#     207             ex2.append(j)
# --> 208             driver=exception3()
#     209             continue
#     210             '''service = Service('chromedriver')
#
# <ipython-input-11-c54dbf00fde8> in exception3()
#      72     print('j loop 3')
#      73     time.sleep(40)
# ---> 74     driver.find_element_by_xpath("//th[normalize-space()='December 2020']").click()
#      75     time.sleep(40)
#      76     print('j loop 4')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//th[normalize-space()='December 2020']"}
#   (Session info: chrome=86.0.4240.198)

# %%
import pandas as pd
df=pd.DataFrame(list(zip(mon,day,hr,aqi,Apm2,Apm10,Ano2,Anh3,Aso2,Aco,Aoz,minpm2,minpm10,minno2,minnh3,minso2,minco,minoz,maxpm2,maxpm10,maxno2,maxnh3,maxso2,maxco,maxoz)),columns=['Month','Day','Hour','AQI','AvgPM2.5','AvgPM10','AvgNo2','AvgNh3','Avgso2','Avgco','AvgOz','minpm2.5','minpm10','minNo2','minNh3','minSo2','minCo','minOz','maxPM2.5','maxpm10','maxNo2','maxNh3','maxso2','maxco','maxOz'])
df
# Out:
#     Month Day  Hour  AQI AvgPM2.5 AvgPM10 AvgNo2 AvgNh3 Avgso2 Avgco  ...  \
# 0     Jun   1     0                           20      5     15    96  ...
# 1     Jun   1     1                           20      5     15    96  ...
# 2     Jun   1     2                           20      5     15    89  ...
# 3     Jun   1     3                           21      5     16    70  ...
# 4     Jun   1     4                           21      5     16    52  ...
# ..    ...  ..   ...  ...      ...     ...    ...    ...    ...   ...  ...
# 350   Sep   9    15  112       80      77     56      6          114  ...
# 351   Sep   9    16  116       80      77     55      6          114  ...
# 352   Sep   9    17  115       81      78     53      6          114  ...
# 353   Sep   9    18  114       81      76     52      6          115  ...
# 354   Sep   9    19  114       81      74     52      6          115  ...
#
#     minSo2 minCo minOz maxPM2.5 maxpm10 maxNo2 maxNh3 maxso2 maxco maxOz
# 0       13    15    52        -       -     43      6     17   162   128
# 1       13    15    52        -       -     43      6     17   162   128
# 2       13    15    52        -       -     43      6     28   162   128
# 3       13    15    51        -       -     43      6     28   162   128
# 4       13    15    49        -       -     43      6     28   162   128
# ..     ...   ...   ...      ...     ...    ...    ...    ...   ...   ...
# 350      -    50    14      107     169     93      8      -   124    46
# 351      -    50    14      107     169     93      8      -   124    46
# 352      -    50    14      107     169     93      8      -   124    46
# 353      -    50    14      107     169     93      8      -   124    46
# 354      -    50    14      107     169     93      8      -   124    46
#
# [355 rows x 25 columns]

# %%
df.to_excel('SepAQI.xlsx')

# %%
AvgMinMax()
maxco
# Out:
# ['130']
